# %% [markdown]
# # IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
import math

#berguna untuk mengimpor library yang dibutuhkan untuk menyelesaikan tugas regresi linear sederhana.dataset = pd.read_csv(‘R03_excercises.csv’) digunakan untuk mengimpor dataset. dataset.head() berguna untuk memunculkan 5 data teratas dari dataset.

# %%
dataset = pd.read_csv("R03_excercises.csv") # import dataset
dataset.head() # memunculkan 5 data teratas
# Out:
#    Daily Exercise Time (X)  Weight Loss (Y)
# 0                      0.5              0.2
# 1                      1.0              0.4
# 2                      1.5              0.7
# 3                      2.0              1.0
# 4                      1.0              0.3

# %%
print("#jumlah dataset saya : "+str(len(dataset.index))) # memunculkan seluruh jummlah data
#digunakan untuk mengetahui jumlah data pada dataset.
# Out:
# #jumlah dataset saya : 74

# %%
dataset.describe() # melakukan analisis deskriptif otomatis
#untuk melakukan analisis deskriptif secara otomatis terhadap dataset yang dipilih
# Out:
#        Daily Exercise Time (X)  Weight Loss (Y)
# count                74.000000        74.000000
# mean                  2.124324         1.001351
# std                   1.021121         0.567980
# min                   0.400000         0.200000
# 25%                   1.225000         0.500000
# 50%                   2.050000         1.000000
# 75%                   2.975000         1.500000
# max                   3.900000         2.000000

# %% [markdown]
# # PREPROCESSING DATA

# %%
# berfungsi untuk menampilkan grafik plot. Dalam analisis ini, koordinat X merupakan weight loss sedangkan koordinat Y merupakan daily excercise time.
dataset.plot(x='Daily Exercise Time (X)', y='Weight Loss (Y)', style='1')
plt.title('Daily Exercise Time vs Weight Loss')
plt.xlabel('Daily Exercise Time')
plt.ylabel('Weight Loss')
plt.show()

# %%
# digunakan untuk menentukan variabel independen (sumbu X) yaitu weight loss dan menentukan variabel dependen (sumbu Y) yaitu daily excercise time.
x = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

# %%
# adalah pembagian data menjadi dua bagian untuk data training (training set) dan data test (test set), yaitu 80% untuk data training dan 20% untuk data test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
# Digunakan untuk mengimpor class LinearRegression dari library sklearn.linear_model yang diperlukan untuk membuat model regresi. Selanjutnya adalah membuat objek regressor sebagai fungsi dari LinearRegression dan kemudian membuat model regresi untuk data training dengan menuliskan regressor.fit(x_train, y_train)
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# -0.16387567761757382

# %%
print(regressor.coef_)
# Out:
# [0.54776969]

# %%
# perhitungan manual dengan rumus y: intercept+coef*Daily Exercise Time (X)
-0.16387567761757382+0.54776969*1.5
# Out:
# 0.6577788573824261

# %% [markdown]
# ###### Kumpulan kode di atas merupakan prediksi weight loss secara manual. Hasil dari pencarian parameter intercept dan coef nantinya akan di masukan ke dalam rumus y = intercept + coef * daily excercise time dengan hasil seperti diatas

# %%
y_pred = regressor.predict(x_test)

# %%
dataframe = pd.DataFrame({'data sebenarnya' : y_test, 'data prediksi' : y_pred})
dataframe
# Out:
#     data sebenarnya  data prediksi
# 0               1.7       1.588987
# 1               0.8       0.931664
# 2               1.8       1.862872
# 3               1.9       1.808095
# 4               0.3       0.383894
# 5               0.7       0.657779
# 6               0.3       0.274340
# 7               1.4       1.369879
# 8               1.1       1.150772
# 9               1.1       0.931664
# 10              0.6       0.548225
# 11              1.0       1.041218
# 12              1.8       1.753318
# 13              0.7       0.657779
# 14              0.7       0.822110

# %% [markdown]
# ###### Kode di atas berfungsi untuk memprediksi weight loss yang akan didapat berdasarkan daily excercise time secara otomatis

# %% [markdown]
# # VISUALISASI

# %%
sns.pairplot(dataset)
# Menampilkan grafik plot dari data weight loss dan daily excercise time

# %%
# visualisasi hasil test
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color = 'blue')
plt.title('Daily Exercise Time vs Weight Loss(test set)')
plt.xlabel('Daily Exercise Time')
plt.ylabel('Weight Loss')
plt.show()

# Menampilkan hasil dari Test set, di mana koordinat X merupakan weight loss dan koordinat Y merupakan daily excercise time

# %%
# visualisasi hasil training set
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, regressor.predict(x_train), color = 'blue')
plt.title('Daily Exercise Time vs Weight Loss(training set)')
plt.xlabel('Daily Exercise Time')
plt.ylabel('Weight Loss')
plt.show()

# Menampilkan hasil dari Training set, di mana koordinat X merupakan weight loss dan koordinat Y merupakan daily excercise time

# %% [markdown]
# ### Semakin lama berolahraga, maka semakin banyak berat badan yang turun.
